# %% [markdown]
# <a href="https://colab.research.google.com/github/sreekarunity/dolly_use/blob/main/pandas_ai.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Source : https://github.com/gventuri/pandas-ai

# %%
# !pip install pandas

# %%
# !pip install pandasai

# %%
import pandas as pd
from pandasai import PandasAI
from pandasai.llm.openai import OpenAI
from pandasai.llm.op

# %%
# Sample DataFrame
df = pd.DataFrame({
    "patients": ["Jane", "Michael", "Alice", "Olivia", "Jane", "Alice", "Alice", "James", "Sophia", "Jane"],
    "age": [23, 25, 33, 54, 27, 11, 20, 14, 67, 44],
    "gender": ["Male", "Female", "Female", "Female", "Male", "Male", "Female", "Male", "Female", "Male"],
    "Insurance": ['Government',"Private", "Medicare", "Medicare", "Medicare", "Private", "Government", "Government", "Medicare", "None" ],
    "marital status": ["married", "Unknown", "single", "widowed", "divorced","married", "single", "divorced", "divorced",  "married"],
    "Diagnosis": ["Diabetes", "sepsis", "Brain", "Brain", "Diabetes", "Cancer", "Cancer", "Diabetes", "Fever", "Fever"]
})

# %%
display(df)
# Out:
#   patients  age  gender   Insurance marital status Diagnosis
# 0     Jane   23    Male  Government        married  Diabetes
# 1  Michael   25  Female     Private        Unknown    sepsis
# 2    Alice   33  Female    Medicare         single     Brain
# 3   Olivia   54  Female    Medicare        widowed     Brain
# 4     Jane   27    Male    Medicare       divorced  Diabetes
# 5    Alice   11    Male     Private        married    Cancer
# 6    Alice   20  Female  Government         single    Cancer
# 7    James   14    Male  Government       divorced  Diabetes
# 8   Sophia   67  Female    Medicare       divorced     Fever
# 9     Jane   44    Male        None        married     Fever

# %%
# Instantiate a LLM
llm = OpenAI(api_token="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")

# %%
pandas_ai = PandasAI(llm)
pandas_ai(df, prompt='How may patients are available?')
# Out:
# 10

# %%
pandas_ai(df, prompt='How many medicare insurance persons are there?')
# Out:
# 4

# %%
pandas_ai(df, prompt='How may fever patients are there?')
# Out:
# 2

# %%
pandas_ai(df, prompt='How may married patients are there?')
# Out:
# 3

# %%
pandas_ai(df, prompt='How may Male patients are available?')
# Out:
# 5

# %%
pandas_ai(df, prompt='What is the gender of Jane?')
# Out:
# 'Male'

# %%
pandas_ai(df, prompt='what is the dataframe about?')
# Out:
#   patients  age  gender   Insurance marital status Diagnosis
# 0     Jane   23    Male  Government        married  Diabetes
# 1  Michael   25  Female     Private        Unknown    sepsis
# 2    Alice   33  Female    Medicare         single     Brain
# 3   Olivia   54  Female    Medicare        widowed     Brain
# 4     Jane   27    Male    Medicare       divorced  Diabetes
# 5    Alice   11    Male     Private        married    Cancer
# 6    Alice   20  Female  Government         single    Cancer
# 7    James   14    Male  Government       divorced  Diabetes
# 8   Sophia   67  Female    Medicare       divorced     Fever
# 9     Jane   44    Male        None        married     Fever

# %%
pandas_ai(df, prompt='Who is the president of India?')
# Out:
#   patients  age  gender   Insurance marital status Diagnosis
# 0     Jane   23    Male  Government        married  Diabetes
# 1  Michael   25  Female     Private        Unknown    sepsis
# 2    Alice   33  Female    Medicare         single     Brain
# 3   Olivia   54  Female    Medicare        widowed     Brain
# 4     Jane   27    Male    Medicare       divorced  Diabetes

# %%
pandas_ai(df, prompt='who is the murderer?')
# Out:
# ''

# %%
pandas_ai(df, prompt='Who is from India?')
# Out:
# Empty DataFrame
# Columns: [patients, age, gender, Insurance, marital status, Diagnosis]
# Index: []

# %%
pandas_ai(df, prompt='list of married persons?')
# Out:
# ['Jane', 'Alice', 'Jane']

# %%
pandas_ai(df, prompt='list of married persons with age?')
# Out:
#   patients  age
# 0     Jane   23
# 5    Alice   11
# 9     Jane   44

# %%
pandas_ai(df, prompt='list out the persons below 30 years age?')
# Out:
#   patients  age  gender   Insurance marital status Diagnosis
# 0     Jane   23    Male  Government        married  Diabetes
# 1  Michael   25  Female     Private        Unknown    sepsis
# 4     Jane   27    Male    Medicare       divorced  Diabetes
# 5    Alice   11    Male     Private        married    Cancer
# 6    Alice   20  Female  Government         single    Cancer
# 7    James   14    Male  Government       divorced  Diabetes

# %%
pandas_ai(df, prompt='how many male patients are there and list out them with age wise?')
# Out:
# '5   patients  age\n0     Jane   23\n4     Jane   27\n5    Alice   11\n7    James   14\n9     Jane   44'

# %%
pandas_ai(df, prompt='2+2?')
# Out:
# 4

# %%
pandas_ai(df, prompt='what is the IST time?')
# Out:
# Generated code includes import of pytz which is not in whitelist.
# 'Unfortunately, I was not able to answer your question, because of the following error:\n\nGenerated code includes import of pytz which is not in whitelist.\n'

# %%
pandas_ai(df, prompt='who is the prime minister of india?')
# Out:
#   patients  age  gender   Insurance marital status Diagnosis
# 0     Jane   23    Male  Government        married  Diabetes
# 1  Michael   25  Female     Private        Unknown    sepsis
# 2    Alice   33  Female    Medicare         single     Brain
# 3   Olivia   54  Female    Medicare        widowed     Brain
# 4     Jane   27    Male    Medicare       divorced  Diabetes

# %%
pandas_ai(df, prompt='when is independence day in U.S.A?')
# Out:
# '2023-07-04'

# %%
pandas_ai(df, prompt='who is the president of U.S.A?')
# Out:
#   patients  age  gender   Insurance marital status Diagnosis
# 0     Jane   23    Male  Government        married  Diabetes
# 1  Michael   25  Female     Private        Unknown    sepsis
# 2    Alice   33  Female    Medicare         single     Brain
# 3   Olivia   54  Female    Medicare        widowed     Brain
# 4     Jane   27    Male    Medicare       divorced  Diabetes
# 5    Alice   11    Male     Private        married    Cancer
# 6    Alice   20  Female  Government         single    Cancer
# 7    James   14    Male  Government       divorced  Diabetes
# 8   Sophia   67  Female    Medicare       divorced     Fever
# 9     Jane   44    Male        None        married     Fever

# %%
pandas_ai(df, prompt='what is the population of U.S.A?')
# Out:
# 'patients  age  gender   Insurance marital status Diagnosis\n0     Jane   23    Male  Government        married  Diabetes\n1  Michael   25  Female     Private        Unknown    sepsis\n2    Alice   33  Female    Medicare         single     Brain\n3   Olivia   54  Female    Medicare        widowed     Brain\n4     Jane   27    Male    Medicare       divorced  Diabetes\n5    Alice   11    Male     Private        married    Cancer\n6    Alice   20  Female  Government         single    Cancer\n7    James   14    Male  Government       divorced  Diabetes\n8   Sophia   67  Female    Medicare       divorced     Fever\n9     Jane   44    Male        None        married     Fever\nPopulation of U.S.A: 10'

# %%
pandas_ai(df, prompt='when GPT-3 released?')
# Out:
#   patients  age  gender   Insurance marital status Diagnosis
# 0     Jane   23    Male  Government        married  Diabetes
# 1  Michael   25  Female     Private        Unknown    sepsis
# 2    Alice   33  Female    Medicare         single     Brain
# 3   Olivia   54  Female    Medicare        widowed     Brain
# 4     Jane   27    Male    Medicare       divorced  Diabetes
# 5    Alice   11    Male     Private        married    Cancer
# 6    Alice   20  Female  Government         single    Cancer
# 7    James   14    Male  Government       divorced  Diabetes
# 8   Sophia   67  Female    Medicare       divorced     Fever
# 9     Jane   44    Male        None        married     Fever

# %%
pandas_ai(df, prompt='when is independence day in India')
# Out:
#   patients  age  gender   Insurance marital status Diagnosis
# 0     Jane   23    Male  Government        married  Diabetes
# 1  Michael   25  Female     Private        Unknown    sepsis
# 2    Alice   33  Female    Medicare         single     Brain
# 3   Olivia   54  Female    Medicare        widowed     Brain
# 4     Jane   27    Male    Medicare       divorced  Diabetes
# 5    Alice   11    Male     Private        married    Cancer
# 6    Alice   20  Female  Government         single    Cancer
# 7    James   14    Male  Government       divorced  Diabetes
# 8   Sophia   67  Female    Medicare       divorced     Fever
# 9     Jane   44    Male        None        married     Fever

# %%
pandas_ai(df, prompt='what is A.T.M?')
# Out:
#   patients  age  gender   Insurance marital status Diagnosis
# 0     Jane   23    Male  Government        married  Diabetes
# 1  Michael   25  Female     Private        Unknown    sepsis
# 2    Alice   33  Female    Medicare         single     Brain
# 3   Olivia   54  Female    Medicare        widowed     Brain
# 4     Jane   27    Male    Medicare       divorced  Diabetes

# %%
pandas_ai(df, prompt='what is the national game in U.S.A?')
# Out:
#   patients  age  gender   Insurance marital status Diagnosis
# 0     Jane   23    Male  Government        married  Diabetes
# 1  Michael   25  Female     Private        Unknown    sepsis
# 2    Alice   33  Female    Medicare         single     Brain
# 3   Olivia   54  Female    Medicare        widowed     Brain
# 4     Jane   27    Male    Medicare       divorced  Diabetes
# 5    Alice   11    Male     Private        married    Cancer
# 6    Alice   20  Female  Government         single    Cancer
# 7    James   14    Male  Government       divorced  Diabetes
# 8   Sophia   67  Female    Medicare       divorced     Fever
# 9     Jane   44    Male        None        married     Fever

# %%
pandas_ai(df, prompt='what is the full form of U.S.A?')
# Out:
# No code found in the response
# 'Unfortunately, I was not able to answer your question, because of the following error:\n\nNo code found in the response\n'

# %%
pandas_ai(df, prompt='what is age of jane?')
# Out:
# 23

# %%
pandas_ai(df, prompt='what is the value of pi?')
# Out:
# Generated code includes import of math which is not in whitelist.
# 'Unfortunately, I was not able to answer your question, because of the following error:\n\nGenerated code includes import of math which is not in whitelist.\n'

# %%
import math

# %%
pandas_ai(df, prompt='what is the value of pi?')
# Out:
# Generated code includes import of math which is not in whitelist.
# 'Unfortunately, I was not able to answer your question, because of the following error:\n\nGenerated code includes import of math which is not in whitelist.\n'

# %%
pandas_ai(df, prompt='List out the users , whose name is alice?')
# Out:
#   patients  age  gender   Insurance marital status Diagnosis
# 2    Alice   33  Female    Medicare         single     Brain
# 5    Alice   11    Male     Private        married    Cancer
# 6    Alice   20  Female  Government         single    Cancer

# %%
pandas_ai(df, prompt='list out the cancer patients')
# Out:
#   patients  age  gender   Insurance marital status Diagnosis
# 5    Alice   11    Male     Private        married    Cancer
# 6    Alice   20  Female  Government         single    Cancer

# %%
pandas_ai(df, prompt='list out the private insurance patients')
# Out:
#   patients  age  gender Insurance marital status Diagnosis
# 1  Michael   25  Female   Private        Unknown    sepsis
# 5    Alice   11    Male   Private        married    Cancer

# %%
# !pip install pandas

# %%
# !pip install gpt_index

# %%
import gpt_index
import pandas as pd

# Load the dataframe
# df = pd.read_csv("data.csv")

# Create a GPTIndex object
index = gpt_index.GPTIndex(df)

# Index the dataframe
index.index()

# Query the dataframe
response = index.query("What is the average age of the people in the dataframe?")

print(response)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-7-9e7a25e4098a> in <cell line: 1>()
# ----> 1 import gpt_index
#       2 import pandas as pd
#       3
#       4 # Load the dataframe
#       5 # df = pd.read_csv("data.csv")
#
# ModuleNotFoundError: No module named 'gpt_index'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------
